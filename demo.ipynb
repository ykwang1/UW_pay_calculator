# %%
from wage_calculator import Wage_Calculator

calc = Wage_Calculator()
# Out:
# /home/tom/Documents/coding/UW_pay_calculator/wage_calculator.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.base_real_wages.loc[:,year] = (self.base_real_wages[int(year - 1)] * self.base_net_increase[year])#.astype(int)
# /home/tom/Documents/coding/UW_pay_calculator/wage_calculator.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.astro_real_wages.loc[:,year] = (self.astro_real_wages[int(year - 1)] * self.astro_net_increase[year])#.astype(int)
# ...

# %%
# Get all data from 2020-21 year to 2026-27 year
print(calc)
# Out:
# Base Pay:
#                2021   2022   2023   2024   2025   2026   2027
# premaster     $2436  $2510  $2586  $2664  $2984  $3282  $3610
# intermediate  $2618  $2698  $2779  $2863  $3135  $3448  $3793
# candidate     $2813  $2899  $2986  $3076  $3291  $3620  $3983
#
# Astro Pay:
#                2021   2022   2023   2024   2025   2026   2027
# premaster     $2923  $3012  $3103  $3197  $3293  $3359  $3610
# intermediate  $3142  $3238  $3335  $3436  $3539  $3610  $3793
# candidate     $3376  $3479  $3583  $3691  $3802  $3878  $3983
# ____________________
#
# Astro Pay is Base Pay:
#                2021   2022   2023   2024   2025   2026  2027
# premaster     False  False  False  False  False  False  True
# intermediate  False  False  False  False  False  False  True
# candidate     False  False  False  False  False  False  True
# ____________________
#
# Base Gross Increases:
#               2022  2023  2024   2025   2026   2027
# premaster     3.0%  3.0%  3.0%  12.0%  10.0%  10.0%
# ...

# %% [markdown]
# ### Plot base and astro wages

# %%
calc.plot_gross_wages(fte60=False)

# %% [markdown]
# ### Plot inflation adjusted base and astro wages
#
# Assuming 3.5%, 3%, 3% inflation over the next 3 years

# %%
calc.plot_net_wages(wages2021_astro=True, plot_base=True, fte60=False)

# %% [markdown]
# ### Use this cell to change inflation rates

# %%
# calc.change_inflation_rates([4, 3.5, 3.5])

# %% [markdown]
# ### Use this cell to change astro pay rates

# %%
# calc.change_pay_increases("astro", "premaster")
# calc.change_pay_increases("astro", "intermediate")
# calc.change_pay_increases("astro", "candidate")

# %% [markdown]
# ### Re print and plot new data

# %%
print(calc)
# Out:
# Base Pay:
#                2021   2022   2023   2024   2025   2026   2027
# premaster     $2436  $2510  $2586  $2664  $2984  $3282  $3610
# intermediate  $2618  $2698  $2779  $2863  $3135  $3448  $3793
# candidate     $2813  $2899  $2986  $3076  $3291  $3620  $3983
#
# Astro Pay:
#                2021   2022   2023   2024   2025   2026   2027
# premaster     $2923  $3012  $3103  $3197  $3293  $3359  $3610
# intermediate  $3142  $3238  $3335  $3436  $3539  $3610  $3793
# candidate     $3376  $3479  $3583  $3691  $3802  $3878  $3983
# ____________________
#
# Astro Pay is Base Pay:
#                2021   2022   2023   2024   2025   2026  2027
# premaster     False  False  False  False  False  False  True
# intermediate  False  False  False  False  False  False  True
# candidate     False  False  False  False  False  False  True
# ____________________
#
# Base Gross Increases:
#               2022  2023  2024   2025   2026   2027
# premaster     3.0%  3.0%  3.0%  12.0%  10.0%  10.0%
# ...

# %%
calc.plot_gross_wages(fte60=False)

calc.plot_net_wages(wages2021_astro=True, plot_base=True, fte60=False)
